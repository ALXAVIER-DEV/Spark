# %% [markdown]
# <a href="https://colab.research.google.com/github/ALXAVIER-DEV/Spark/blob/master/Aula_2_Spark_Day_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## PySpark no Google Colab
#
# PySpark é uma interface alto nível que permite você programar na linguagem Python e processar dados.
#
# Já o Google Colab é uma ferramenta de notebook gratuita e online.
# 100% na nuvem, sem necessidade de instalar na maquina. porém ele tem duranção de uma sessão.
#
# A instalação do Spark dentro do Colab não é direto como um pip install.
# Então precisamos de alguns passos antes de iniciar nossa aula ou para quando for praticar em casa.

# %%
# instalar as dependências
# baixando a versão mais recente do java8;
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
#download via stp do hadoop
# !wget -q https://archive.apache.org/dist/spark/spark-2.4.4/spark-2.4.4-bin-hadoop2.7.tgz
#extraindo o arquivo tgz
# !tar xf spark-2.4.4-bin-hadoop2.7.tgz
#instalando o  Findspark que é responsavel para que as variáveis ​​do ambiente sejam definidas corretamente e o pyspark seja importado.
# !pip install -q findspark

# %% [markdown]
# Nessa etapa abaixo configuramo as variáveis de ambiente.

# %%
import os
#configurando as variáveis de ambiente, para  que o colab identifique corretamente onde as dependencias estão rodando.
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-2.4.4-bin-hadoop2.7"

# utilizando o findspark para que o pyspark seja "importável"
import findspark
findspark.init('spark-2.4.4-bin-hadoop2.7')

# %% [markdown]
# **Recapitulando... Spark Session!**
#
# Todo programa python com uso da biblioteca spark, necessita de um ponto de entrada para se comunicar com as fontes de dados e o cluster.
#
# No Spark, nós utilizamos o SparkSession, que será uma variável de ambiente contendo a classe SparkSession que faz a comunicação com cluster.
#
# também, para usarmos operações de coluna em um dataframe necessitamos importar as funções de SQL.
#
# ![Slide2.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# também, aprendemos que dentro do big data é comum existir uma arquitetura para que todos os fluxos de trabalho acontecam da maneira certa...
#
# e que através do spark, nós consumimos os dados de várias origens e realizamos operações de modelagem de dados...
#
# que uma arquitetura de big data, possuem camada como Landing-Zone, Raw, Context e Application.
#
# e que cada camada possui uma caracteristica...
#
# ![Capturar.PNG](data:image/png;base64,...)
#
#
# [Linkedin Post](https://www.linkedin.com/feed/update/urn:li:share:6965296535123206144/?utm_source=linkedin_share&utm_medium=member_desktop_share&utm_content=post/)

# %% [markdown]
# **camada raw**
#
# essa camada possui o objetivo de pegar os dados despejados pelos extratores em containers/buckets, e processar levando esse registro de forma bruta para o datalake, aplicando metadados e também ajustando os tipos de dados das colunas.
#
# **artigo sobre automatização de ingestão de informações**
#
# [Medium Luiza Labs](https://medium.com/luizalabs/automatizando-a-ingest%C3%A3o-de-dados-no-data-lake-badceae7a4c5)

# %% [markdown]
# **Bora botar a mão na massa e criar o de ingestão centralizando o código.**

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F 
import datetime

str_now = datetime.datetime.now().strftime("%Y-%n-%d %H:%M-%S")
spark = SparkSession.builder.getOrCreate()

df = spark.read.option('header','true').option('delimiter','|').csv('/mnt/cadastro/Class.docx')
df = df.dropDuplicates()\
.withColums
# Out:
#   File "<ipython-input-5-453e6ff44409>", line 8
#     df = spark.read.option('header','true').option('delimiter;,'|').csv('/mnt/cadastro/Class.docx')
#                                                                                                    ^
# SyntaxError: EOL while scanning string literal

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# **Lazzi Evaluation**
#
# dentro do spark, algumas ações nos dataframes não possuem chamada de execução, então o spark acumula essas ações e transformam elas em estágios para depois distribuir essas tarefas entre os executores, tornando assim o processamento dos dados ainda mais poderoso!
#
# ![stage.png](data:image/png;base64,...)

# %% [markdown]
# **Ok... bora pra proxima parte! como eu posso modelar esses dados filtrando as informações e também sumarizando elas?**

# %% [markdown]
# **primeiro vamos falar sobre booleanos...**
#
# Na programação, muitas vezes nós precisamos saber se uma expressão é Verdadeira ou False.
#
# Você pode testar uma expressão lógica com Python e obter uma das duas respostas, True ou False.
#
# Quando você compara dois valores, a expressão é avaliada e o Python retorna a resposta booleana:

# %% [markdown]
# tá... o python então interpreta todas as condições logicas como verdadeiro ou falso, e assim ele traça os fluxos dentro do código.
#
# **mas qual relação com spark?**
#
# primeiro vamos ver isso acontecendo também.

# %% [markdown]
# vou ordenar o dataframe para melhorar a visualização

# %% [markdown]
# e isso é usado em toda sua estrutura de processamento.
#
# **já q entendemos como funciona os booleanos, vamos falar sobre filtros:**

# %% [markdown]
# **de forma bem básica... como frazer agrupamentos?**

# %% [markdown]
# **somar os dados!**

# %% [markdown]
# **O minimo :(**

# %% [markdown]
# **o maximo!**

# %% [markdown]
# **realizar contagens!**

# %% [markdown]
# **Obrigado pela participação!!**

# %% [markdown]
# **Importante!**
#
# ![7039feef2b5057539d06d959d5ec23a4.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2022-08-19 at 12.54.25.jpeg](data:image/jpeg;base64,...)
